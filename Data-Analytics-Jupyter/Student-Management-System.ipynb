# %% [markdown]
# # Student Management System
# * Beginner friendly python project to learn jupyter notebook usage and python (Object Oriented)
# * WILL PROCEED ONCE I AM DONE WITH SQL REVISION TO ENTER DB ALSO
