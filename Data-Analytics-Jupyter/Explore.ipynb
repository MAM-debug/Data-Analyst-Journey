# %% [markdown]
# # Hey Exploring Jupyter Notebook
# ## Concepts in Jupyter Notebook
# ### So lets get started
# ---
# * TASK 1
# ctrl + enter to stay in same cell and ctrl + shift to save and move to next
# esc + enter to go in any cell . always install all libraries in your virtual env

# %%
print ("hello world")
# Out:
# hello world

# %%
print ("Hello again")
print ("I like typing this.")
# Out:
# Hello again
# I like typing this.

# %% [markdown]
# # this is another markdown cell
# ---
# * list
# * another list

# %%
import numpy as np
